# %% [markdown]
# # info

# %% [markdown]
# *   list=[]
# *   tuple=()
# *   dict={1:"a",2:"c"}
# *   set={}

# %% [markdown]
# x=[1,3,5,6]
#
# y=[1,5,7,9]
#
# y=mx+c
#
# y_hat=[8,6,4,6]

# %% [markdown]
# # **Mean Absolute Error**

# %%
#wap to implement mean absolute error

def MAE(x,y,w,b):
    sum=0
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
        sum+=abs(y_hat[i]-y[i])
    print("Predicted Output: ",y_hat)
    return sum/len(x)

x=[3,6,9,12,15,18,20]
y=[15,28,63,90,120,152,190]
w=eval(input("Enter the values of w: "))
b=eval(input("Enter the value of b: "))
print("Actual Output: ",y)
print("Mean Absolute Error: ",MAE(x, y, w, b))
# Out:
# Enter the values of w: 2
# Enter the value of b: 0
# Actual Output:  [15, 28, 63, 90, 120, 152, 190]
# Predicted Output:  [6, 12, 18, 24, 30, 36, 40]
# Mean Absolute Error:  70.28571428571429

# %% [markdown]
# # **Mean Square Error**

# %%
#wap to implement mean square error

def MSE(x,y,w,b):
    sq_sum=0
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
        sq_sum+=(y_hat[i]-y[i])**2
    print("Predicted Output: ",y_hat)
    return sq_sum/len(x)

x=[3,6,9,12,15,18,20]
y=[15,28,63,90,120,152,190]
w=eval(input("Enter the values of w: "))
b=eval(input("Enter the value of b: "))
print("Actual Output: ",y)
print("Mean Square Error: ",MSE(x ,y ,w ,b))
# Out:
# Enter the values of w: 4
# Enter the value of b: 0
# Actual Output:  [15, 28, 63, 90, 120, 152, 190]
# Predicted Output:  [12, 24, 36, 48, 60, 72, 80]
# Mean Square Error:  3516.8571428571427

# %% [markdown]
# # **Mean Absolute Error & Mean Square Error**

# %%
#wap to implement mean absolute error and mean square error
#input is w & b

def errors(x,y,w,b):
    sum=0
    sq_sum=0
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
        sum+=abs(y_hat[i]-y[i])
        sq_sum+=(y_hat[i]-y[i])**2
    print("Predicted Output: ",y_hat)
    mae=sum/len(x)
    mse=sq_sum/len(x)
    return mae,mse

overs=[3,6,9,12,15,18,20]
a_run=[15,28,63,90,120,152,190]
w=eval(input("Enter the values of w: "))
b=eval(input("Enter the value of b: "))
print("Actual Output: ",a_run)
MAE,MSE=errors(overs,a_run,w,b)
print("Mean Absolute Error: ",MAE)
print("Mean Square Error: ",MSE)
# Out:
# Enter the values of w: 1.5
# Enter the value of b: 0
# Actual Output:  [15, 28, 63, 90, 120, 152, 190]
# Predicted Output:  [4.5, 9.0, 13.5, 18.0, 22.5, 27.0, 30.0]
# Mean Absolute Error:  76.21428571428571
# Mean Square Error:  8405.25

# %%
#wap to implement mean absolute error and mean square error
#input is (list of w) & b

def errors(x,y,w,b):
    sum=0
    sq_sum=0
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
        sum+=abs(y_hat[i]-y[i])
        sq_sum+=(y_hat[i]-y[i])**2
    print("Predicted values: ",y_hat)
    return sum/len(x),sq_sum/len(x)

overs=[3,6,9,12,15,18,20]
a_run=[15,28,63,90,120,152,190]
w=[eval(x) for x in input("Enter the values of w: ").split()]
b=eval(input("Enter the value of b: "))
for i in w:
    print("For w:",i)
    MAE,MSE=errors(overs,a_run,i,b)
    print("Mean Absolute Error: ",MAE)
    print("Mean Square Error: ",MSE)
# Out:
# Enter the values of w: -1
# Enter the value of b: 0
# For w: -1
# Predicted values:  [-3, -6, -9, -12, -15, -18, -20]
# Mean Absolute Error:  105.85714285714286
# Mean Square Error:  15470.42857142857

# %%
#input is x, y, w, b
def errors(x,y,w,b):
    sum=0
    sq_sum=0
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
        sum+=abs(y_hat[i]-y[i])
        sq_sum+=(y_hat[i]-y[i])**2
    print("Predicted values: ",y_hat)
    return sum/len(x),sq_sum/len(x)

x=[eval(x) for x in input("Enter the values of x(input): ").split(",")]
y=[eval(x) for x in input("Enter the values of y(output): ").split(",")]
w=eval(input("Enter the value of w: "))
b=eval(input("Enter the value of b: "))
MAE,MSE=errors(x,y,w,b)
print("Mean Absolute Error: ",MAE)
print("Mean Square Error: ",MSE)
# Out:
# Enter the values of x(input): 3,6,9,12,15,18,20
# Enter the values of y(output): 15,28,63,90,120,152,190
# Enter the value of w: 2
# Enter the value of b: 0
# Predicted values:  [6, 12, 18, 24, 30, 36, 40]
# Mean Absolute Error:  70.28571428571429
# Mean Square Error:  7253.428571428572

# %%
#function to calculate the predicted values
def predicted_output(x,w,b):
    y_hat=[]
    for i in range(len(x)):
        y_hat.append(w*x[i]+b)
    return y_hat

#function to calculate mean absolute error
def MAE(y, y_hat):
    sum=0
    for i in range(len(y)):
        sum+=abs(y_hat[i]-y[i])
    return sum/len(y)

#function to calculate mean square error
def MSE(y, y_hat):
    sq_sum=0
    for i in range(len(y)):
        sq_sum+=(y_hat[i]-y[i])**2
    return sq_sum/len(y)

#taking inputs
x=[eval(x) for x in input("Enter the values of x(input) separated by ',': ").split(",")]
y=[eval(x) for x in input("Enter the values of y(output) separated by ',': ").split(",")]
w=eval(input("Enter the value of w: "))
b=eval(input("Enter the value of b: "))
#calling functions
y_hat=predicted_output(x, w, b)
MAE_value=MAE(y, y_hat)
MSE_value=MSE(y, y_hat)
#printing the values
print("Predicted Output: ",y_hat)
print("Mean Absolute Error: ",MAE_value)
print("Mean Square Error: ",MSE_value)
# Out:
# Enter the values of x(input) separated by ',': 3, 6, 9, 12, 15, 18, 20
# Enter the values of y(output) separated by ',': 15,28,63,90,120,152,190
# Enter the value of w: 2
# Enter the value of b: 0
# Prdicted Output:  [6, 12, 18, 24, 30, 36, 40]
# Mean Absolute Error:  70.28571428571429
# Mean Square Error:  7253.428571428572
